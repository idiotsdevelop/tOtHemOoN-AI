# %%
import numpy as np

a = np.random.random((10, 10, 3))
b = np.random.random((10, 10, 3))

# %%
b[b[:]>0.5] = 1

# %%
b
# Out:
# array([[[1.        , 1.        , 0.20740583],
#         [0.26245855, 0.14909277, 0.0745941 ],
#         [1.        , 1.        , 1.        ],
#         [1.        , 1.        , 0.47900064],
#         [0.33124125, 0.33013869, 1.        ],
#         [1.        , 0.37879314, 1.        ],
#         [0.1869257 , 1.        , 0.32509487],
#         [0.14690644, 1.        , 0.14317458],
#         [0.34653877, 0.41575094, 1.        ],
#         [1.        , 1.        , 1.        ]],
#
#        [[0.48179372, 1.        , 1.        ],
#         [1.        , 1.        , 1.        ],
#         [0.49468935, 0.38744569, 1.        ],
#         [1.        , 1.        , 0.40313463],
#         [1.        , 1.        , 1.        ],
#         [0.07712374, 1.        , 0.40253954],
#         [0.3086538 , 0.40683033, 1.        ],
#         [0.01310463, 1.        , 0.2233929 ],
#         [1.        , 1.        , 0.04491783],
#         [0.47678163, 1.        , 1.        ]],
#
# ...
